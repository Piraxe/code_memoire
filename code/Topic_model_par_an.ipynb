# %%
import pandas as pd
import numpy as np

#Graphes
import igraph as ig
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from ipysigma import Sigma
import matplotlib.pyplot as plt
import spacy
#Parcours de documents et tokenisation
import os
from tqdm import tqdm
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import csv
#LDA
import gensim
from gensim import corpora
import logging
import time
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# %% [markdown]
# # Topic Modeling par année

# %% [markdown]
# #### Etape 1 : Prendre des courts extraits aléatoires de chaque séance

# %%
# Fonction pour importer les documents et les regrouper par années
def ouverture_documents(chemin_dossier):
    liste_fichiers = os.listdir(chemin_dossier)
    documents_par_annee = {}
    
    for fichier in tqdm(liste_fichiers):
        with open(os.path.join(chemin_dossier, fichier), 'r', encoding="utf-8") as texte:
            seance = texte.read()
        
        # Extraction de l'année à partir du nom du fichier
        annee = fichier[:4]
        
        # Ajout du contenu du document à la liste de l'année correspondante
        if annee not in documents_par_annee:
            documents_par_annee[annee] = []
        documents_par_annee[annee].append(seance)
    
    return documents_par_annee

# %%
chemin_dossier = "C:/Users/portable_laura/Documents/coursM1/Mémoire/Sources/ocr_sorted"
docus_par_annee = ouverture_documents(chemin_dossier)
# Out:
# 100%|██████████| 7461/7461 [02:37<00:00, 47.48it/s]

# %%
import random
def extraits_aleatoires(documents_par_annee, longueur_souhaitee=15000):
    extraits_par_annee = {}

    for annee, documents in tqdm(documents_par_annee.items()):
        extraits_par_annee[annee] = []
        for document in documents:
            longueur_chaine = len(document)
            if longueur_chaine <= longueur_souhaitee:
                extraits_par_annee[annee].append(document)
            else:
                #prend un index de départ aléatoire entre le début de la chaîne et le dernier index permettant d'obtenir une chaine de la longueur souhaitée
                index = random.randint(0, longueur_chaine - longueur_souhaitee)
                extraits_par_annee[annee].append(document[index:index + longueur_souhaitee])
    
    return extraits_par_annee

# %%
extraits_docus = extraits_aleatoires(docus_par_annee)
extraits_docus.keys()
# Out:
# 100%|██████████| 60/60 [00:07<00:00,  7.66it/s]
# dict_keys(['1881', '1882', '1883', '1884', '1885', '1886', '1887', '1888', '1889', '1890', '1891', '1892', '1893', '1894', '1895', '1896', '1897', '1898', '1899', '1900', '1901', '1902', '1903', '1904', '1905', '1906', '1907', '1908', '1909', '1910', '1911', '1912', '1913', '1914', '1915', '1916', '1917', '1918', '1919', '1920', '1921', '1922', '1923', '1924', '1925', '1926', '1927', '1928', '1929', '1930', '1931', '1932', '1933', '1934', '1935', '1936', '1937', '1938', '1939', '1940'])

# %% [markdown]
# #### Etape 2 : Tokeniser chaque année

# %%
nltk.download('stopwords')
nltk.download('punkt')
stopwords_fr = stopwords.words('french')


#Remplir manuellement les mots qui semblent pertinents dans le contexte des débats parlementaires de la troisième république
stopwords_fr.extend([
    'monsieur', 'madame',"présidences",'présidents', 'président',"secrétaires","présidente","voix","bureau",'secrétaire', 'ministre', 'rapporteur', 'commission', 'député', 'sénateur', 'assemblée', 'sénat', 'parlement', 'république', 'projet', 'loi', 'amendement', 
    'article', 'alinéa', 'vote', 'scrutin', 'débat', 'intervention', 'orateur', 'gouvernement', 'commission', 
    'question', 'réponse', 'session', 'ordre', 'jour', 'discussion', 'texte', 'examen', 'proposition', 'hémicycle', 
    'session', 'majorité', 'minorité', 'opposition', 'camarade', 'camarades', 'débat', 'interventions', 'présidence', 
    'directeur', 'décision', 'pouvoir', 'réunion', 'groupes', 'parlementaire', 'parlementaires', 'politique', 
    'politiques', 'publique', 'public', 'publique', 'privé', 'privée', 'national', 'nationale', 'nation', 'nations', 
    'citoyen', 'citoyenne', 'citoyens', 'citoyennes', 'mesdames', 'messieurs', 'collègue', 'collègues', 'disposition', 
    'dispositions',"comme","cette","être","an","","dit","sée","a","rapp","si","si","do","dit","a","bien","plus","cette","mm","dont","parce","e","très","si"
])


with open("C:/Users/portable_laura/Documents/coursM1/Mémoire/Code/stop_words_french.txt","r",encoding="utf-8") as fichier:
    stopwords_ajout = fichier.read()
    
stopwords_ajout = stopwords_ajout.replace('\n', ' ')
    
liste_stopwords = stopwords_ajout.split()

stopwords_fr.extend(liste_stopwords)

print(stopwords_fr)
print(len(stopwords_fr))
# Out:
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'aurez', 'auront', 'aurais', 'aurait', 'aurions', 'auriez', 'auraient', 'avais', 'avait', 'avions', 'aviez', 'avaient', 'eut', 'eûmes', 'eûtes', 'eurent', 'aie', 'aies', 'ait', 'ayons', 'ayez', 'aient', 'eusse', 'eusses', 'eût', 'eussions', 'eussiez', 'eussent', 'monsieur', 'madame', 'présidences', 'présidents', 'président', 'secrétaires', 'présidente', 'voix', 'bureau', 'secrétaire', 'ministre', 'rapporteur', 'commission', 'député', 'sénateur', 'assemblée', 'sénat', 'parlement', 'république', 'projet', 'loi', 'amendement', 'article', 'alinéa', 'vote', 'scrutin', 'débat', 'intervention', 'orateur', 'gouvernement', 'commission', 'question', 'réponse', 'session', 'ordre', 'jour', 'discussion', 'texte', 'examen', 'proposition', 'hémicycle', 'session', 'majorité', 'minorité', 'opposition', 'camarade', 'camarades', 'débat', 'interventions', 'présidence', 'directeur', 'décision', 'pouvoir', 'réunion', 'groupes', 'parlementaire', 'parlementaires', 'politique', 'politiques', 'publique', 'public', 'publique', 'privé', 'privée', 'national', 'nationale', 'nation', 'nations', 'citoyen', 'citoyenne', 'citoyens', 'citoyennes', 'mesdames', 'messieurs', 'collègue', 'collègues', 'disposition', 'dispositions', 'comme', 'cette', 'être', 'an', '', 'dit', 'sée', 'a', 'rapp', 'si', 'si', 'do', 'dit', 'a', 'bien', 'plus', 'cette', 'mm', 'dont', 'parce', 'e', 'très', 'si', 'a', 'abord', 'absolument', 'afin', 'ah', 'ai', 'aie', 'aient', 'aies', 'ailleurs', 'ainsi', 'ait', 'allaient', 'allo', 'allons', 'allô', 'alors', 'anterieur', 'anterieure', 'anterieures', 'apres', 'après', 'as', 'assez', 'attendu', 'au', 'aucun', 'aucune', 'aucuns', 'aujourd', "aujourd'hui", 'aupres', 'auquel', 'aura', 'aurai', 'auraient', 'aurais', 'aurait', 'auras', 'aurez', 'auriez', 'aurions', 'aurons', 'auront', 'aussi', 'autant', 'autre', 'autrefois', 'autrement', 'autres', 'autrui', 'aux', 'auxquelles', 'auxquels', 'avaient', 'avais', 'avait', 'avant', 'avec', 'avez', 'aviez', 'avions', 'avoir', 'avons', 'ayant', 'ayez', 'ayons', 'b', 'bah', 'bas', 'basee', 'bat', 'beau', 'beaucoup', 'bien', 'bigre', 'bon', 'boum', 'bravo', 'brrr', 'c', 'car', 'ce', 'ceci', 'cela', 'celle', 'celle-ci', 'celle-là', 'celles', 'celles-ci', 'celles-là', 'celui', 'celui-ci', 'celui-là', 'celà', 'cent', 'cependant', 'certain', 'certaine', 'certaines', 'certains', 'certes', 'ces', 'cet', 'cette', 'ceux', 'ceux-ci', 'ceux-là', 'chacun', 'chacune', 'chaque', 'cher', 'chers', 'chez', 'chiche', 'chut', 'chère', 'chères', 'ci', 'cinq', 'cinquantaine', 'cinquante', 'cinquantième', 'cinquième', 'clac', 'clic', 'combien', 'comme', 'comment', 'comparable', 'comparables', 'compris', 'concernant', 'contre', 'couic', 'crac', 'd', 'da', 'dans', 'de', 'debout', 'dedans', 'dehors', 'deja', 'delà', 'depuis', 'dernier', 'derniere', 'derriere', 'derrière', 'des', 'desormais', 'desquelles', 'desquels', 'dessous', 'dessus', 'deux', 'deuxième', 'deuxièmement', 'devant', 'devers', 'devra', 'devrait', 'different', 'differentes', 'differents',  ...
# 1744
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\portable_laura\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\portable_laura\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Preprocessing des documents - fonction
def preprocess(doc_texte):
    doc_texte = doc_texte.lower()
    doc_texte = re.sub(r'[^\w\sÀ-ÿ]', ' ', doc_texte)  # Utilisation de la plage Unicode pour inclure les caractères français
    doc_texte = re.sub(r'\d+', ' ', doc_texte)
    words = word_tokenize(doc_texte, language='french')  # Tokenization pour le français
    
    words = [word for word in words if word not in stopwords_fr]  # Utilisation de mots vides en français, cette liste est à modifier et a agrémenter des mots vides correspondant au corpus
    return words

# %%
def preprocess_extraits(extraits_par_annee):
    preprocessed_extraits = {}

    for annee, extraits in extraits_par_annee.items():
        preprocessed_extraits[annee] = []
        for extrait in tqdm(extraits, desc=f"Préprocessing de l'année {annee}", leave=False):
            preprocessed_extraits[annee].append(preprocess(extrait))
    
    return preprocessed_extraits

# %%
dico_extraits_preprocess = preprocess_extraits(extraits_docus)

# %%
import json
#On enregistre le dictionnaire dans un fichier json afin de pouvoir l'exploiter à nouveau par la suite

fichier_json = "C:/Users/portable_laura/Documents/coursM1/Mémoire/Code/dico_extraits_preprocess_15000.json"

with open(fichier_json, 'w', encoding='utf-8') as fichier:
    json.dump(dico_extraits_preprocess, fichier, ensure_ascii=False, indent=4)

# %% [markdown]
# #### Etape 3 : Déterminer les sujets pour chaque année ou tranche d'années

# %%
def create_lda_and_save_topics(dico, filename):
    all_topics = []

    for key, docs in dico.items():
        dictionary = corpora.Dictionary(docs)
        corpus = [dictionary.doc2bow(doc) for doc in tqdm(docs, desc=f"Création du corpus pour {key}")]

        num_topics = 20
        passes = 20

        lda_model = gensim.models.LdaModel(
            corpus, 
            num_topics=num_topics, 
            id2word=dictionary, 
            passes=passes,
        )

        for idx, topic in lda_model.print_topics(-1):
            all_topics.append([key, idx, topic])

    topics_df = pd.DataFrame(all_topics, columns=['Key', 'Topic Index', 'Words'])
    topics_df.to_csv(filename, index=False)

create_lda_and_save_topics(dico_extraits_preprocess, 'C:/Users/portable_laura/Documents/coursM1/Mémoire/Code/lda_topics_test_avec_15000.csv')
# Out:
# Création du corpus pour 1881: 100%|██████████| 122/122 [00:00<00:00, 427.74it/s]
# Création du corpus pour 1882: 100%|██████████| 255/255 [00:00<00:00, 945.21it/s]
# Création du corpus pour 1883: 100%|██████████| 146/146 [00:00<00:00, 619.36it/s]
# Création du corpus pour 1884: 100%|██████████| 153/153 [00:00<00:00, 619.30it/s]
# Création du corpus pour 1885: 100%|██████████| 122/122 [00:00<00:00, 769.73it/s]
# Création du corpus pour 1886: 100%|██████████| 116/116 [00:00<00:00, 878.41it/s]
# Création du corpus pour 1887: 100%|██████████| 82/82 [00:00<00:00, 896.10it/s]
# Création du corpus pour 1888: 100%|██████████| 155/155 [00:00<00:00, 863.35it/s]
# Création du corpus pour 1889: 100%|██████████| 119/119 [00:00<00:00, 1101.15it/s]
# Création du corpus pour 1890: 100%|██████████| 128/128 [00:00<00:00, 855.98it/s]
# Création du corpus pour 1891: 100%|██████████| 138/138 [00:00<00:00, 828.25it/s]
# Création du corpus pour 1892: 100%|██████████| 114/114 [00:00<00:00, 882.70it/s]
# Création du corpus pour 1893: 100%|██████████| 133/133 [00:00<00:00, 1127.36it/s]
# Création du corpus pour 1894: 100%|██████████| 120/120 [00:00<00:00, 793.57it/s]
# Création du corpus pour 1895: 100%|██████████| 130/130 [00:00<00:00, 780.36it/s]
# Création du corpus pour 1896: 100%|██████████| 192/192 [00:00<00:00, 1278.15it/s]
# Création du corpus pour 1897: 100%|██████████| 146/146 [00:00<00:00, 1282.65it/s]
# Création du corpus pour 1898: 100%|██████████| 117/117 [00:00<00:00, 712.81it/s]
# Création du corpus pour 1899: 100%|██████████| 108/108 [00:00<00:00, 1300.78it/s]
# Création du corpus pour 1900: 100%|██████████| 118/118 [00:00<00:00, 1030.24it/s]
# Création du corpus pour 1901: 100%|██████████| 113/113 [00:00<00:00, 921.26it/s]
# Création du corpus pour 1902: 100%|██████████| 99/99 [00:00<00:00, 956.03it/s]
# Création du corpus pour 1903: 100%|██████████| 130/130 [00:00<00:00, 865.56it/s]
# Création du corpus pour 1904: 100%|██████████| 132/132 [00:00<00:00, 915.01it/s]
# Création du corpus pour 1905: 100%|██████████| 133/133 [00:00<00:00, 942.48it/s]
# Création du corpus pour 1906: 100%|██████████| 111/111 [00:00<00:00, 920.32it/s]
# Création du corpus pour 1907: 100%|██████████| 123/123 [00:00<00:00, 1091.90it/s]
# Création du corpus pour 1908: 100%|██████████| 124/124 [00:00<00:00, 1003.18it/s]
# Création du corpus pour 1909: 100%|██████████| 195/195 [00:00<00:00, 924.00it/s]
# Création du corpus pour 1910: 100%|██████████| 120/120 [00:00<00:00, 676.03it/s]
# Création du corpus pour 1911: 100%|██████████| 158/158 [00:00<00:00, 987.02it/s]
# Création du corpus pour 1912: 100%|██████████| 112/112 [00:00<00:00, 1080.99it/s]
# Création du corpus pour 1913: 100%|██████████| 156/156 [00:00<00:00, 904.37it/s]
# Création du corpus pour 1914: 100%|██████████| 90/90 [00:00<00:00, 1145.40it/s]
# Création du corpus pour 1915: 100%|██████████| 95/95 [00:00<00:00, 967.84it/s]
# Création du corpus pour 1916: 100%|██████████| 143/143 [00:00<00:00, 768.90it/s]
# Création du corpus pour 1917: 100%|██████████| 149/149 [00:00<00:00, 938.63it/s]
# Création du corpus pour 1918: 100%|██████████| 142/142 [00:00<00:00, 1002.09it/s]
# Création du corpus pour 1919: 100%|██████████| 184/184 [00:00<00:00, 949.54it/s]
# Création du corpus pour 1920: 100%|██████████| 134/134 [00:00<00:00, 760.50it/s]
# Création du corpus pour 1921: 100%|██████████| 147/147 [00:00<00:00, 783.83it/s]
# Création du corpus pour 1922: 100%|██████████| 143/143 [00:00<00:00, 874.30it/s]
# Création du corpus pour 1923: 100%|██████████| 145/145 [00:00<00:00, 820.18it/s]
# Création du corpus pour 1924: 100%|██████████| 149/149 [00:00<00:00, 782.31it/s]
# Création du corpus pour 1925: 100%|██████████| 135/135 [00:00<00:00, 783.86it/s]
# Création du corpus pour 1926: 100%|██████████| 122/122 [00:00<00:00, 871.57it/s]
# Création du corpus pour 1927: 100%|██████████| 111/111 [00:00<00:00, 818.22it/s]
# Création du corpus pour 1928: 100%|██████████| 96/96 [00:00<00:00, 791.99it/s]
# Création du corpus pour 1929: 100%|██████████| 114/114 [00:00<00:00, 697.02it/s]
# Création du corpus pour 1930: 100%|██████████| 98/98 [00:00<00:00, 916.86it/s]
# Création du corpus pour 1931: 100%|██████████| 108/108 [00:00<00:00, 901.39it/s]
# Création du corpus pour 1932: 100%|██████████| 93/93 [00:00<00:00, 864.57it/s]
# Création du corpus pour 1933: 100%|██████████| 108/108 [00:00<00:00, 793.17it/s]
# Création du corpus pour 1934: 100%|██████████| 92/92 [00:00<00:00, 872.04it/s]
# Création du corpus pour 1935: 100%|██████████| 77/77 [00:00<00:00, 1004.84it/s]
# Création du corpus pour 1936: 100%|██████████| 98/98 [00:00<00:00, 1025.66it/s]
# Création du corpus pour 1937: 100%|██████████| 85/85 [00:00<00:00, 970.62it/s]
# Création du corpus pour 1938: 100%|██████████| 63/63 [00:00<00:00, 1050.05it/s]
# Création du corpus pour 1939: 100%|██████████| 67/67 [00:00<00:00, 975.88it/s]
# Création du corpus pour 1940: 100%|██████████| 53/53 [00:00<00:00, 1039.55it/s]

# %%
nom_fichier = 'C:/Users/portable_laura/Documents/coursM1/Mémoire/Code/lda_topics_test_avec_15000.csv'

pd.set_option('display.max_colwidth', None)
topics_df = pd.read_csv(nom_fichier)

topics_df.head(40)
# Out:
#      Key  Topic Index  \
# 0   1881            0
# 1   1881            1
# 2   1881            2
# 3   1881            3
# 4   1881            4
# 5   1881            5
# 6   1881            6
# 7   1881            7
# 8   1881            8
# 9   1881            9
# 10  1881           10
# 11  1881           11
# 12  1881           12
# 13  1881           13
# 14  1881           14
# 15  1881           15
# 16  1881           16
# 17  1881           17
# 18  1881           18
# 19  1881           19
# 20  1882            0
# 21  1882            1
# 22  1882            2
# 23  1882            3
# 24  1882            4
# 25  1882            5
# 26  1882            6
# 27  1882            7
# 28  1882            8
# 29  1882            9
# 30  1882           10
# 31  1882           11
# 32  1882           12
# 33  1882           13
# 34  1882           14
# 35  1882           15
# 36  1882           16
# 37  1882           17
# 38  1882           18
# 39  1882           19
#
#                                                                                                                                                                                                Words
# 0                                    0.008*"chambre" + 0.006*"droit" + 0.006*"demande" + 0.003*"gauche" + 0.003*"service" + 0.003*"fr" + 0.003*"heure" + 0.003*"lieu" + 0.003*"heures" + 0.003*"ans"
# 1                                0.006*"chambre" + 0.005*"gauche" + 0.005*"demande" + 0.005*"fr" + 0.004*"droit" + 0.004*"france" + 0.003*"pays" + 0.003*"ministère" + 0.003*"faut" + 0.003*"guerre"
# 2                                   0.019*"dépôt" + 0.018*"fer" + 0.014*"chemin" + 0.012*"objet" + 0.008*"publ" + 0.006*"utilité" + 0.006*"adopt" + 0.006*"ligne" + 0.005*"déclarat" + 0.005*"saint"
# 3                           0.007*"chambre" + 0.005*"demande" + 0.004*"officiers" + 0.004*"gauche" + 0.004*"armée" + 0.003*"fr" + 0.002*"droit" + 0.002*"moment" + 0.002*"chabrié" + 0.002*"freppel"
# 4         0.011*"nombre" + 0.010*"inscrits" + 0.010*"exprimés" + 0.010*"suffrages" + 0.010*"quart" + 0.008*"électeurs" + 0.008*"obtenu" + 0.008*"bulletins" + 0.007*"protestation" + 0.007*"votants"
# 5           0.006*"ouvriers" + 0.004*"droit" + 0.004*"chambre" + 0.004*"provisoire" + 0.003*"outrage" + 0.003*"syndicales" + 0.003*"vice" + 0.003*"délit" + 0.003*"associations" + 0.002*"beauquier"
# 6                         0.005*"cuirassés" + 0.003*"nombre" + 0.003*"police" + 0.003*"gauche" + 0.003*"prieu" + 0.003*"point" + 0.003*"service" + 0.003*"budget" + 0.002*"etat" + 0.002*"situation"
# 7                        0.011*"chambre" + 0.006*"gauche" + 0.005*"droit" + 0.005*"demande" + 0.004*"budget" + 0.003*"membres" + 0.002*"etat" + 0.002*"lieu" + 0.002*"syndicats" + 0.002*"haentjens"
# 8                                0.008*"adopté" + 0.007*"chambre" + 0.007*"art" + 0.006*"travaux" + 0.006*"budget" + 0.005*"millions" + 0.004*"etat" + 0.004*"dépenses" + 0.004*"droit" + 0.003*"fr"
# 9                    0.007*"électeurs" + 0.005*"provost" + 0.005*"launay" + 0.004*"nord" + 0.004*"tracé" + 0.003*"gauche" + 0.003*"arrondissement" + 0.003*"chambre" + 0.003*"even" + 0.003*"préfet"
# 10                                  0.008*"louis" + 0.004*"loire" + 0.004*"seine" + 0.004*"nord" + 0.004*"georges" + 0.004*"jules" + 0.004*"paul" + 0.003*"martin" + 0.003*"henri" + 0.003*"chambre"
# 11                      0.006*"millions" + 0.006*"chambre" + 0.005*"art" + 0.004*"papier" + 0.004*"adopté" + 0.003*"bulletins" + 0.003*"tendant" + 0.003*"finances" + 0.003*"haentjens" + 0.003*"fr"
# 12                             0.008*"fr" + 0.005*"compagnie" + 0.005*"dépense" + 0.005*"etat" + 0.004*"fer" + 0.004*"millions" + 0.004*"agents" + 0.003*"chambre" + 0.003*"paris" + 0.003*"demande"
# 13                0.010*"hommes" + 0.009*"ladoucette" + 0.007*"budget" + 0.005*"millions" + 0.005*"guerre" + 0.004*"armée" + 0.004*"chambre" + 0.004*"finances" + 0.003*"argent" + 0.003*"électeurs"
# 14                            0.007*"divorce" + 0.005*"enfants" + 0.004*"mariage" + 0.003*"droit" + 0.003*"séparation" + 0.003*"père" + 0.003*"civil" + 0.003*"époux" + 0.003*"vaut" + 0.003*"femme"
# 15                              0.000*"chambre" + 0.000*"nombre" + 0.000*"droit" + 0.000*"demande" + 0.000*"fr" + 0.000*"budget" + 0.000*"fer" + 0.000*"gauche" + 0.000*"adopté" + 0.000*"électeurs"
# 16                   0.006*"chambre" + 0.006*"commerce" + 0.005*"chaussure" + 0.004*"port" + 0.004*"chaussures" + 0.004*"travail" + 0.003*"guerre" + 0.003*"repos" + 0.003*"soulier" + 0.003*"farcy"
# 17                                   0.000*"chambre" + 0.000*"demande" + 0.000*"gauche" + 0.000*"droit" + 0.000*"budget" + 0.000*"fr" + 0.000*"nombre" + 0.000*"etat" + 0.000*"guerre" + 0.000*"ans"
# 18                                 0.000*"chambre" + 0.000*"gauche" + 0.000*"demande" + 0.000*"fr" + 0.000*"budget" + 0.000*"droit" + 0.000*"nombre" + 0.000*"etat" + 0.000*"adopté" + 0.000*"louis"
# 19                   0.007*"chambre" + 0.005*"gauche" + 0.003*"applaudissements" + 0.003*"pays" + 0.003*"emprunt" + 0.003*"droit" + 0.003*"jury" + 0.003*"demande" + 0.003*"nombre" + 0.002*"heures"
# 20           0.010*"chambre" + 0.007*"officiers" + 0.007*"nomination" + 0.005*"crédit" + 0.005*"marine" + 0.004*"députés" + 0.004*"exercice" + 0.004*"heures" + 0.004*"démission" + 0.004*"résultat"
# 21                0.008*"droit" + 0.005*"chambre" + 0.004*"fils" + 0.004*"méline" + 0.004*"considération" + 0.003*"tissus" + 0.003*"demande" + 0.003*"france" + 0.003*"intérêts" + 0.003*"industrie"
# 22  0.011*"indigènes" + 0.007*"colonisation" + 0.006*"indigène" + 0.005*"algérie" + 0.003*"hectares" + 0.003*"ballue" + 0.003*"propriétaires" + 0.003*"colons" + 0.003*"population" + 0.003*"fautes"
# 23                               0.010*"chambre" + 0.005*"demande" + 0.004*"gauche" + 0.003*"budget" + 0.003*"droit" + 0.003*"ligne" + 0.003*"point" + 0.003*"etat" + 0.003*"france" + 0.002*"bancs"
# 24                         0.005*"chambre" + 0.004*"intérêt" + 0.003*"liberté" + 0.003*"demande" + 0.003*"dis" + 0.003*"gauche" + 0.003*"crois" + 0.003*"impôt" + 0.003*"france" + 0.003*"invalides"
# 25                                0.012*"seine" + 0.007*"loire" + 0.006*"nord" + 0.006*"georges" + 0.005*"inférieure" + 0.005*"paul" + 0.005*"saint" + 0.005*"léon" + 0.005*"marne" + 0.005*"martin"
# 26                0.004*"chambre" + 0.003*"tendant" + 0.002*"projets" + 0.002*"honneur" + 0.002*"etat" + 0.002*"autoriser" + 0.002*"département" + 0.002*"reçu" + 0.002*"crédits" + 0.001*"dépenses"
# 27                           0.006*"chambre" + 0.005*"administration" + 0.005*"gauche" + 0.004*"etat" + 0.004*"demande" + 0.003*"point" + 0.003*"ans" + 0.003*"guerre" + 0.003*"fr" + 0.003*"adopté"
# 28                        0.006*"budget" + 0.005*"gauche" + 0.004*"chambre" + 0.004*"procès" + 0.004*"fr" + 0.004*"demande" + 0.004*"france" + 0.003*"instruction" + 0.003*"verbal" + 0.003*"egypte"
# 29                                0.006*"serment" + 0.005*"viandes" + 0.005*"gauche" + 0.004*"pays" + 0.004*"millions" + 0.004*"fr" + 0.003*"etat" + 0.003*"faut" + 0.003*"salées" + 0.002*"bourses"
# 30             0.011*"divorce" + 0.009*"enseignement" + 0.006*"enfants" + 0.005*"mariage" + 0.004*"chambre" + 0.004*"corps" + 0.004*"gauche" + 0.004*"nombre" + 0.004*"freppel" + 0.003*"séparation"
# 31                      0.005*"intérêt" + 0.004*"point" + 0.003*"barodet" + 0.003*"liberté" + 0.003*"matière" + 0.003*"cahiers" + 0.002*"demande" + 0.002*"bancs" + 0.002*"chambre" + 0.002*"gauche"
# 32                0.012*"chambre" + 0.006*"demande" + 0.006*"gauche" + 0.004*"considération" + 0.004*"prise" + 0.004*"droit" + 0.003*"renvoi" + 0.003*"pétition" + 0.003*"commune" + 0.003*"honneur"
# 33                                 0.006*"chambre" + 0.003*"gauche" + 0.003*"art" + 0.003*"tribunal" + 0.002*"adopté" + 0.002*"lieu" + 0.002*"roche" + 0.002*"marine" + 0.002*"etat" + 0.002*"saint"
# 34                   0.010*"chambre" + 0.007*"demande" + 0.006*"pétition" + 0.003*"laroche" + 0.003*"motifs" + 0.003*"renvoi" + 0.003*"pétitions" + 0.003*"gauche" + 0.003*"propose" + 0.003*"crois"
# 35                   0.008*"gauche" + 0.006*"ferry" + 0.005*"jules" + 0.005*"paul" + 0.004*"département" + 0.003*"cassagnac" + 0.003*"grève" + 0.003*"ouvriers" + 0.003*"pensions" + 0.003*"chambre"
# 36                   0.006*"tribunal" + 0.006*"chambre" + 0.005*"demande" + 0.005*"paix" + 0.004*"justice" + 0.003*"renvoi" + 0.003*"acte" + 0.003*"olographe" + 0.003*"intérieur" + 0.003*"volonté"
# 37                       0.010*"budget" + 0.009*"millions" + 0.008*"chambre" + 0.006*"travaux" + 0.005*"dépenses" + 0.005*"fr" + 0.005*"fer" + 0.005*"demande" + 0.005*"exercice" + 0.005*"finances"
# 38                           0.007*"gauche" + 0.006*"budget" + 0.005*"chambre" + 0.004*"faut" + 0.004*"freppel" + 0.003*"demande" + 0.003*"écoles" + 0.003*"crédits" + 0.003*"eglise" + 0.003*"pays"
# 39               0.005*"fr" + 0.003*"budget" + 0.003*"convention" + 0.003*"français" + 0.003*"officiers" + 0.003*"anglais" + 0.002*"roche" + 0.002*"chapitre" + 0.002*"dépenses" + 0.002*"compagnie"
